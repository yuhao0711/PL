# %%
import pandas as pd

data = pd.read_csv("anime.csv")

# %%
data
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
#Q1.過濾評分人數低於10000的資料並重新存取

data = data[data['members'] >= 10000]
data.to_csv('data_filter.csv', index=False)

data_filter = pd.read_csv("data_filter.csv")

# %%
data_filter
# Out:
#       anime_id                              name  \
# 0        32281                    Kimi no Na wa.
# 1         5114  Fullmetal Alchemist: Brotherhood
# 2        28977                          Gintama°
# 3         9253                       Steins;Gate
# 4         9969                     Gintama&#039;
# ...        ...                               ...
# 2985       651  Green Green Thirteen: Erolutions
# 2986       724                             Enzai
# 2987      5391                     Pico to Chico
# 2988      4866               Pico x CoCo x Chico
# 2989      1639                      Boku no Pico
#
#                                                   genre   type episodes  \
# 0                  Drama, Romance, School, Supernatural  Movie        1
# 1     Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                      Sci-Fi, Thriller     TV       24
# 4     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                 ...    ...      ...
# 2985                            Comedy, Hentai, Romance    OVA        1
# 2986                               Hentai, Horror, Yaoi    OVA        2
# 2987                                       Hentai, Yaoi    OVA        1
# 2988                                       Hentai, Yaoi    OVA        1
# 2989                                       Hentai, Yaoi    OVA        1
#
#       rating  members
# 0       9.37   200630
# 1       9.26   793665
# 2       9.25   114262
# 3       9.17   673572
# 4       9.16   151266
# ...      ...      ...
# 2985    6.26    17805
# 2986    5.55    13711
# 2987    5.19    29463
# 2988    5.16    27411
# 2989    5.13    57355
#
# [2990 rows x 7 columns]

# %%
#Q2.將資料排序並重新存取

data_filter = data_filter.sort_values(by='rating', ascending=False)
data_filter.to_csv('data_sorted.csv', index=False)

data_sort = pd.read_csv("data_sorted.csv")

# %%
data_sort
# Out:
#       anime_id                                               name  \
# 0        32281                                     Kimi no Na wa.
# 1         5114                   Fullmetal Alchemist: Brotherhood
# 2        28977                                           Gintama°
# 3         9253                                        Steins;Gate
# 4         9969                                      Gintama&#039;
# ...        ...                                                ...
# 2985     34161                                     Overlord Movie
# 2986     30736                   Shingeki no Bahamut: Virgin Soul
# 2987     33036  Suki ni Naru Sono Shunkan wo.: Kokuhaku Jikkou...
# 2988     34086                     Tales of Zestiria the X (2017)
# 2989     33581  Trinity Seven Movie: Eternity Library to Alche...
#
#                                                   genre   type episodes  \
# 0                  Drama, Romance, School, Supernatural  Movie        1
# 1     Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                      Sci-Fi, Thriller     TV       24
# 4     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                 ...    ...      ...
# 2985  Action, Adventure, Fantasy, Game, Magic, Super...  Movie        1
# 2986  Action, Adventure, Demons, Fantasy, Magic, Sup...     TV       24
# 2987                     Comedy, Drama, Romance, School  Movie        1
# 2988                         Action, Adventure, Fantasy     TV       12
# 2989  Action, Comedy, Ecchi, Fantasy, Harem, Magic, ...  Movie        1
#
#       rating  members
# 0       9.37   200630
# 1       9.26   793665
# 2       9.25   114262
# 3       9.17   673572
# 4       9.16   151266
# ...      ...      ...
# 2985     NaN    16008
# 2986     NaN    20953
# 2987     NaN    10668
# 2988     NaN    10848
# 2989     NaN    19813
#
# [2990 rows x 7 columns]

# %%
#Q3.擷取其中排名前十的資料

data_head = data_sort.head(10)

# %%
data_head
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6     11061                             Hunter x Hunter (2011)
# 7       820                               Ginga Eiyuu Densetsu
# 8     15417                           Gintama&#039;: Enchousen
# 9     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports     TV       10    9.15
# 6            Action, Adventure, Shounen, Super Power     TV      148    9.13
# 7                     Drama, Military, Sci-Fi, Space    OVA      110    9.11
# 8  Action, Comedy, Historical, Parody, Samurai, S...     TV       13    9.11
# 9  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266
# 5    93351
# 6   425855
# 7    80679
# 8    81109
# 9    72534

# %%
#Q4.將內容翻譯成中文

import re
from googletrans import Translator

translator = Translator()

# 建立Translator物件
translator = Translator()

# 定義翻譯函式
def translate_text(text):
    # 將text轉換成字串
    text = str(text)
    # 翻譯並返回結果
    return Translator().translate(text, dest='zh-tw').text

data_translate = data_head.applymap(translate_text)

data_translate.to_csv('data_translate.csv', index=False)

data_translate = pd.read_csv('data_translate.csv')

# %%
data_translate
# Out:
#    anime_id                                              name  \
# 0     32281                                             你是唯一。
# 1      5114                                        鋼鐵煉金術士：兄弟會
# 2     28977                                          gintama°
# 3      9253                                             命運石之門
# 4      9969                                     Gintama＆＃039;
# 5     32935  haikyu！呢：karasu no ko vs shiratori zawaga kuenko
# 6     11061                             Hunter X Hunter（2011）
# 7       820                                           銀河英雄的傳奇
# 8     15417                                    Gintama＆＃039;：
# 9     15335                        gintamamoゔ:: ::ゔゔかかかかかかかか：
#
#                        genre type  episodes  rating  members
# 0               戲劇，浪漫，學校，超自然   電影         1    9.37   200630
# 1  動作，冒險，戲劇，幻想，魔術，軍事，shounen   電視        64    9.26   793665
# 2  動作，喜劇，歷史，模仿，武士，科幻，Shounen   電視        51    9.25   114262
# 3                     科幻，驚悚片   電視        24    9.17   673572
# 4  動作，喜劇，歷史，模仿，武士，科幻，Shounen   電視        51    9.16   151266
# 5        喜劇，戲劇，學校，Shounen，體育   電視        10    9.15    93351
# 6         動作，冒險，shounen，超級力量   電視       148    9.13   425855
# 7                戲劇，軍事，科幻，太空  ova       110    9.11    80679
# 8  動作，喜劇，歷史，模仿，武士，科幻，Shounen   電視        13    9.11    81109
# 9  動作，喜劇，歷史，模仿，武士，科幻，Shounen   電影         1    9.10    72534

# %%
#Q5.翻譯修正(將作品名稱替換成中文譯名、將無法翻譯的文字替換掉)

#讀取英文名稱
name_list = data_head["name"].to_list()
print(name_list)

# 定義新名稱的list
new_names = ['你的名字', '鋼之煉金術師：Fullmetal Alchemist', '銀魂第四季', '命運石之門', '銀魂第三季', '排球少年！！烏野高中 VS 白鳥沢學園高中', '獵人（2011）', '銀河英雄傳說', '銀魂第二季延長', '銀魂劇場版 完結篇 永遠的萬事屋']

# 使用新名稱覆蓋name欄位內容
data_translate.loc[:, 'name'] = new_names

#替換掉無法翻譯的字
data_translate['genre'] = data_translate['genre'].str.replace('shounen', '少年')
data_translate['genre'] = data_translate['genre'].str.replace('Shounen', '少年')
# Out:
# ['Kimi no Na wa.', 'Fullmetal Alchemist: Brotherhood', 'Gintama°', 'Steins;Gate', 'Gintama&#039;', 'Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou', 'Hunter x Hunter (2011)', 'Ginga Eiyuu Densetsu', 'Gintama&#039;: Enchousen', 'Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare']

# %%
data_translate
# Out:
#    anime_id                        name                 genre type  episodes  \
# 0     32281                        你的名字          戲劇，浪漫，學校，超自然   電影         1
# 1      5114  鋼之煉金術師：Fullmetal Alchemist  動作，冒險，戲劇，幻想，魔術，軍事，少年   電視        64
# 2     28977                       銀魂第四季  動作，喜劇，歷史，模仿，武士，科幻，少年   電視        51
# 3      9253                       命運石之門                科幻，驚悚片   電視        24
# 4      9969                       銀魂第三季  動作，喜劇，歷史，模仿，武士，科幻，少年   電視        51
# 5     32935       排球少年！！烏野高中 VS 白鳥沢學園高中        喜劇，戲劇，學校，少年，體育   電視        10
# 6     11061                    獵人（2011）         動作，冒險，少年，超級力量   電視       148
# 7       820                      銀河英雄傳說           戲劇，軍事，科幻，太空  ova       110
# 8     15417                     銀魂第二季延長  動作，喜劇，歷史，模仿，武士，科幻，少年   電視        13
# 9     15335            銀魂劇場版 完結篇 永遠的萬事屋  動作，喜劇，歷史，模仿，武士，科幻，少年   電影         1
#
#    rating  members
# 0    9.37   200630
# 1    9.26   793665
# 2    9.25   114262
# 3    9.17   673572
# 4    9.16   151266
# 5    9.15    93351
# 6    9.13   425855
# 7    9.11    80679
# 8    9.11    81109
# 9    9.10    72534

# %%
#Q6.篩選出最受歡迎的類型前三名
from collections import Counter
import itertools

#以逗號作切分
genre_list = data_translate['genre'].str.split('，')

# 將元組列表轉換成計數器物件
counter = Counter(itertools.chain(*genre_list))

# 取出前三多的元素，只包含元素名称
top3 = [element[0] for element in counter.most_common(3)]

# %%
top3
# Out:
# ['少年', '動作', '科幻']

# %%
#Q7.找出同時具有前三受歡迎類型的作品

# 將 top_three 轉換為一個集合
top3_set = set(top3)

# 過濾出包含 top_three 中所有元素的子列表
filtered_data = data_translate[data_translate['genre'].apply(lambda x: all(i in x for i in top3_set))]
name_list = filtered_data['name'].tolist()

# %%
name_list
# Out:
# ['銀魂第四季', '銀魂第三季', '銀魂第二季延長', '銀魂劇場版 完結篇 永遠的萬事屋']

# %%
#Q8.不具有前三受歡迎元素的作品

#使用了波浪號(~)來排除包含任何一個元素的情況
filtered_data2 = data_translate[~data_translate['genre'].apply(lambda x: any(i in x for i in top3_set))]
name_list2 = filtered_data2['name'].tolist()

# %%
name_list2
# Out:
# ['你的名字']

# %%
#Q9.篩選出最不受歡迎的類型前三名

# 取出前三少的元素，只包含元素名称
last3 = [element[0] for element in counter.most_common()[-3:]]

# %%
last3
# Out:
# ['體育', '超級力量', '太空']

# %%
#Q10.不具有不受歡迎元素的作品

#使用了波浪號(~)來排除包含任何一個元素的情況
filtered_data3 = data_translate[~data_translate['genre'].apply(lambda x: any(i in x for i in last3))]
name_list3 = filtered_data3['name'].tolist()

# %%
name_list3
# Out:
# ['你的名字',
#  '鋼之煉金術師：Fullmetal Alchemist',
#  '銀魂第四季',
#  '命運石之門',
#  '銀魂第三季',
#  '銀魂第二季延長',
#  '銀魂劇場版 完結篇 永遠的萬事屋']
